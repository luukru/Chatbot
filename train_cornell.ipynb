# %% [markdown]
# ### Import Data + Modules

# %%
# These commands download the necessary data and modules from Luuk's github account and place them in the expected folders.
  # (NOTE: we used python 3 and a notebook on Google Colab to run this)

# !rm -rf Bot
# !rm -rf raw_data
# !git clone --recursive https://github.com/luukru/Bot.git
# !cp -r Bot/raw_data .
# Out:
# Cloning into 'Bot'...
# remote: Counting objects: 39, done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 39 (delta 14), reused 33 (delta 8), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from Bot import data
from Bot import data_utils
from Bot import seq2seq_wrapper

# %% [markdown]
# ### Seq2seq

# %%
# Preprocess data
data.process_data()
# Out:
# >> gathered id2line dictionary.
#
# [['L447', 'L448'], ['L490', 'L491'], ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'], ['L750', 'L751', 'L752', 'L753', 'L754', 'L755']]
# >> gathered conversations.
#
#
# >> Filter lines
#
# >> 2nd layer of filtering
# 28% filtered from original data
# q : [you hate me dont you]; a : [i dont really think you warrant that strong an emotion]
# q : [then say youll spend dollar night at the track with me]; a : [and why would i do that]
# q : [come on  the ponies the flat beer you with money in your eyes me with my hand on your ass]; a : [you  covered in my vomit]
# q : [are you following me]; a : [i was in the laundromat i saw your car thought id say hi]
#
# >> Segment lines into words
#
# :: Sample from segmented list of words
# q : [['you', 'hate', 'me', 'dont', 'you']]; a : [['i', 'dont', 'really', 'think', 'you', 'warrant', 'that', 'strong', 'an', 'emotion']]
# q : [['then', 'say', 'youll', 'spend', 'dollar', 'night', 'at', 'the', 'track', 'with', 'me']]; a : [['and', 'why', 'would', 'i', 'do', 'that']]
# q : [['come', 'on', 'the', 'ponies', 'the', 'flat', 'beer', 'you', 'with', 'money', 'in', 'your', 'eyes', 'me', 'with', 'my', 'hand', 'on', 'your', 'ass']]; a : [['you', 'covered', 'in', 'my', 'vomit']]
# q : [['are', 'you', 'following', 'me']]; a : [['i', 'was', 'in', 'the', 'laundromat', 'i', 'saw', 'your', 'car', 'thought', 'id', 'say', 'hi']]
#
#  >> Index words
#
#  >> Filter Unknowns
# 2% filtered from original data
#
#  Final dataset len : 96473
#
#  >> Zero Padding
#
#  >> Save numpy arrays to disk
# % unknown : 4.27073242918805
# Dataset count : 96473

# %%
import importlib
importlib.reload(data)
# Out:
# <module 'Bot.data' from '/content/Bot/data.py'>

# %%
# Load preprocessed data from pickle and npy files
metadata, idx_q, idx_a = data.load_data(PATH='')

# Divide data into training, test and validation sets.
(trainX, trainY), (testX, testY), (validX, validY) = data_utils.split_dataset(idx_q, idx_a)

# %%
# The seq2seq model parameters 
xseq_len = trainX.shape[-1]
yseq_len = trainY.shape[-1]
batch_size = 16
xvocab_size = len(metadata['idx2w'])  
yvocab_size = len(metadata['idx2w'])  
print(len(metadata['idx2w']))
emb_dim = 1024
# Out:
# 8002

# %%
# Initialize the model
model = seq2seq_wrapper.Seq2Seq(xseq_len=xseq_len,
                               yseq_len=yseq_len,
                               xvocab_size=xvocab_size,
                               yvocab_size=yvocab_size,
                               ckpt_path='ckpt/',
                               emb_dim=emb_dim,
                               num_layers=3,
                                epochs=100000
                               )
# Out:
# <log> Building Graph </log>

# %%
# Generate validation, test and train batches by sampling from their respective datasets.
val_batch_gen = data_utils.rand_batch_gen(validX, validY, 32)
test_batch_gen = data_utils.rand_batch_gen(testX, testY, 256)
train_batch_gen = data_utils.rand_batch_gen(trainX, trainY, batch_size)

# %%
# Restore session and continue training

#sess = model.restore_last_session()
#sess = model.train(train_batch_gen, val_batch_gen, sess)

# Start training from scratch
sess = model.train(train_batch_gen, val_batch_gen)
# Out:
# <log> Training started </log>
#
# Model saved to disk at iteration #1000
# val   loss : 2.021551
# Interrupted by user at iteration 1132

# %%
# Restore variables from disk.
sess = model.restore_last_session()
  
input_ = test_batch_gen.__next__()[0]
output = model.predict(sess, input_)
print(output.shape)

# %%
# Print 1 question and answer pair, for each unique answer generated by model.
replies = []
for ii, oi in zip(input_.T, output):
    q = data_utils.decode(sequence=ii, lookup=metadata['idx2w'], separator=' ')
    decoded = data_utils.decode(sequence=oi, lookup=metadata['idx2w'], separator=' ').split(' ')
    if decoded.count('unk') == 0:
        if decoded not in replies:
            print('q : [{0}]; a : [{1}]'.format(q, ' '.join(decoded)))
            replies.append(decoded)
# Out:
# q : [hes lying]; a : [i cant believe my triangle says triangle and balls up the coon and then everyone has to]
# q : [very nice okay last one]; a : [wait hello you guys like ass with him in a bad shot]
# q : [cartman come on]; a : [yeah this is awesome]
# q : [they told us he has a mmuscular disease an and that and that he he might die]; a : [yeah i have those have some more ho]
# q : [oh hey kid good luck good luck]; a : [yes yes am how much its a little piggy]
# q : [and then give me the twenty and ill give you the pubes]; a : [fuck you fucking tricked]
# q : [i think if we try kennys neighborhood we might find a]; a : [yes i hate you guys]
# q : [maybe you got brain cancer]; a : [okay butters you wanna go butters]
# q : [well the prostate seems to be normal no swelling of the hemorrhoidal gland]; a : [yeah is the new mom is not in the future]
# q : [go fuck yourself cartman]; a : [hey guys just a good you guys have to get a gun bronco]
# q : [were sorry butters our mind is made up]; a : [yeah so gonna get it of here]
# q : [hooray christmas tree christmas tree christmas tree]; a : [youre my god this mom its my mom says you can do it about my mom is going to be a skateboard]
# q : [soon theyll discover frozen food gohho]; a : [alright let you think be a little piggy for a second for a second]
# q : [bloomin taj mahal]; a : [its a fabulous billy chef you guys]
# q : [alright class i have your school photos to hand out]; a : [what is a second for a second]
# q : [you put kennys picture on a milk carton]; a : [no way this is had a long time for a total time]
# q : [yeah and then what]; a : [its not the british kyle you guys the nuts is gonna get the nuts and the drunken barn dance]
# q : [were were in trouble were in sooo much trouble]; a : [hey you guys oh guys oh my god]
# q : [are you sure this is what you want sweetie]; a : [oh i dont think were going to be a second you wanna go kyle]
# q : [ah i thought we were speaking for the children]; a : [well im bullcrap of saying bro up]
# q : [oo whats a radiohead]; a : [alright get the whole time for dinner for a nogood sinned]
# q : [cripple fight]; a : [no way]
# q : [hammertime cant the code word just be lookout i wont remember hammertime]; a : [dude my mom kyle you]
# q : [perhaps we could use it to strengthen our star cruisers]; a : [oh yeah we gotta have me ready]
# q : [well what cartman]; a : [kyle you guys]
# q : [there is no such thing as a funny fuse cartman you felt bad]; a : [kyle kyle i dont have to talk about the mall kyle kyle is not a golden dreamcast]
# q : [but i am]; a : [yeah i cant believe this stupid stupid people]
# q : [alright]; a : [its a hate lion]
# q : [what the hell are you doing fatass]; a : [this is not sure you have to be a dead folder]
# q : [youre stupid]; a : [yup a little piggy]
# q : [the sea people on tweeks side just suicidebombed the cartman statue]; a : [okay kyle ahead i have to the mall]
# q : [s]; a : [okay mom you need to start up in our face]
# q : [cartman wake up]; a : [ey oh dont you guys]
# q : [hurry up stupid parachute]; a : [yeah right i have to the commercial]
# q : [heres my snout]; a : [its my ass kyle you can you hear at me stupid glasses]
# q : [hey these are brine shrimp i used to feed them to my fish]; a : [get fine get a bunch of a second kyle and a syringe on a second pass and more everyone can you in the access and]
# q : [stans getting worse you guys]; a : [alright what you guys are you doing a jew]
# q : [yeah that makes it even worse]; a : [yeah good thats cool friend says ass]
# q : [eric god could sure use that money for a bigger church]; a : [i dont wanna go]
# q : [cartman hes crazy]; a : [no no no no nono]
# q : [but buut but but what hey wait a minute]; a : [hey im going to be a long time for a long time for a second]
# q : [man i cant believe how much people want us to get our winning ticket back]; a : [yeah well well i guess you guys have some problems in their scared of the internet and i have to get a miracle of virtual]
# q : [you need to freeze some of your ass off]; a : [i dont know what its not my mom]
# q : [gosh chili rides and ponies what more could i want]; a : [aw man you are a lot of black and confusion in a nogood rowr rowr to prove thanksgiving]
# q : [ookay great well print it immediately]; a : [hes the hell are you gonna get the world to buy me the nuts and phillip shows now are gonna get the nuts]
# q : [and cartman for being fat]; a : [yeah im not fat it is gonna be a second kyle kyle]
# q : [what the hell are you doing here]; a : [what what you are to doing]
# q : [we cant let those sixth graders get their hands on this videotape]; a : [yeah i guess the hell are they go of the future]
# q : [youre gonna smear butters parents walls with poop i thought his revenge was unique and customized]; a : [yeah dude its fucking weak]
# q : [how much did i charge uh oh yeah ten dollars you got change for a twenty]; a : [well im sorry kyle what are you doing to go kyle he mays you guys]
# q : [no way]; a : [sittin on lets go it i have to do it jewpacabra on a second fifty to what]
# q : [dude]; a : [whats the matter of a bitch lucky of a bitch]
# q : [next in line come on lets keep it moving kids]; a : [oh god damnit are such a second]
# q : [yeah thats like that stupid movie contact]; a : [oh yeah that means for a little bit for a while]
# q : [okay now its funny again]; a : [alright butters you guys have a little suit to get the door]
# q : [singing a christmas song isnt gonna get you nice deductions cartman dont forget its because of you that santas sleigh got shot down]; a : [what you have a liar to talk on tv you guys come on a second]
# q : [cartman where are you going]; a : [im not fat is going to get to my friend]
# q : [thats a great idea]; a : [no no way the matter of the producer states]
# q : [i dont know we dont have horses so we cant play]; a : [are you talkin]
# q : [oh well uh okay]; a : [alright you wanna hang]
# q : [cartman just stay out of it]; a : [okay lets go lets go to be your mouth like a while fish for dinner]
# q : [wuh hey now they do too uh my mom and dad love me even if i am fat]; a : [oh god damn it]
# q : [faragon asshole]; a : [ey alright you guys look at her frog in a second heh is gonna have to hide more attractive in the coon for virtual reality]
# q : [ishta fatwa open sesame]; a : [i dont think it was going to get it]
# q : [oh my god eric how long have you been channelin kenny]; a : [no way you sons of bitches]
# q : [taba haqa allah allah allah allah hakadurrpa durpa adurpa hagalah]; a : [oh you oh]
# q : [has russell lost tugger for good find out after these messages]; a : [hey get a big player at jacking and try the sprinkles in south park]
# q : [pick me up i i want to see]; a : [god damn it you guys]
# q : [youre right well now how about timmy hes quiet and he takes direction well]; a : [yeah i am just trying to get some out of our hand]
# q : [aw]; a : [ey chef]
# q : [so we cant let em die douchebag youre our friend now come help us]; a : [im not son of a bitch for you how much you guys]
# q : [someone just has to activate it like the proctologist did]; a : [its not sure]
# q : [you you do how]; a : [how to talk to the mall and i have to have any declaring churshar kyle crack]
# q : [orf course i do]; a : [jesus christ]
# q : [ehh it kind of smells stinky in this condo]; a : [alright alright get to get a little piggy for a second for a second]
# q : [we understand youve seen our son]; a : [yeah i was a did]
# q : [you dont have to kill kyle dude the police made an arrest and the person confessed]; a : [why why my is cool]
# q : [well go on smartass and do it]; a : [no no its raping your triangle]
# q : [hello eric]; a : [hi doctor]
# q : [alright i guess we should taste each others chili huh]; a : [you are really a homo drive you guys]
# q : [yeah we dont like this show]; a : [i love when i was thinking but i can be a problem and then and then i can prove a couple in a shark tank]
# q : [look out here comes the great dragon of perengraph]; a : [huh]
# q : [get up fat boy im gonna kick your ass]; a : [youre gonna have to get a piece of my ass craig]
# q : [well eating sub sandwiches was a big part of it but the way that i lost so much weight was that i got aides]; a : [no no nono i have to get that means i have to get france in the socks and i have a poem depth]
# q : [captain this whole thing is ridiculous]; a : [yeah i knew kyle kyle]
# q : [yeah maybe we should]; a : [oh yeah we we are gonna take us down the hell and try to get a little bit in your mouth]
# q : [you know ive had it you four boys never take art class seriously]; a : [hey what you]
# q : [im not interested]; a : [yeah hes not a thousand right you guys have to do]
# q : [are you guys official presidents too]; a : [why what you are a homo and a swindler and a swindler tattletale for a kidney of a bitch]
# q : [hes losing weight]; a : [hey let were me full of zaron to school for him to me out of here]
# q : [hey cartman i care a lot about him too]; a : [ugh thats not cool be a second little balls]
# q : [thatll be six dollars]; a : [sittin on lets see me it]
# q : [its not]; a : [what does]
# q : [going places that ive never beenseeing things that i may never see a uuugh jesus christ]; a : [yeah this sucks im not paying you guys have to be normal ass]
# q : [and if you look here you can see how david blaine performed the miracle of being frozen in ice at times square]; a : [yes maam you guys guys are such a second kyle is gonna be a while for a month]
# q : [alright its settledcome on butters]; a : [dude whats wrong it]
# q : [im glad youre not that bad poopsiekins]; a : [alright alright you guys]
# q : [oh larry this young man has some new fetuses for research]; a : [hey maybe there im gonna be ass for a price in the meantime person]
# q : [im sorry im sorry damnit im losing them okay im sorry just send out one calf]; a : [oh god you guys damnit seriously]
# q : [just forget it cartman you dont know what youre doing]; a : [im sorry for what]
# q : [youll get over it honey]; a : [stan stan is not a lot more wrist more and more blow and a long what are you doing]
# q : [oh i dont think thatll be hard ive been working on my rr routine]; a : [well well i dont have to be normal thing to time]
# q : [well our son is a perfect voidfiller its nice that he finally has your sons to be his best buddies]; a : [well well hardcore out of a bitch i cant believe of things and then and then during into the virtual]
# q : [hello were mr and mrs thompson]; a : [yeah well we need to get the big magic batmobile johnson in their last and pee up are out of the other jakovasaur]
# q : [nohoho way jos]; a : [well nice looks like a little douchebag youre a little program of a bitch]
# q : [whoa i gotta get out of here]; a : [its not a fabulous its a little piggy its a second its a second]
# q : [well hello eric i was really glad you called me very much]; a : [but i had somebody calamine frog]
# q : [cartman farted in there we had to breath it in for 20 hours]; a : [mom i have to be a little piggy is a liar for having and i have to be a sharp and then i saw]
# q : [damnit damnit thanks a lot kid]; a : [okay okay does to talk to the hotbar kyle kyle is john out of a bitch of your vagina intellect for]
# q : [wait]; a : [oh god i guess you guys know what was a bad situation monkey heh]
# q : [david blaine is doing a big performance in denver tomorrow night were sure his magic will entertain and astound you]; a : [youre what i mean you mean about this mom is the world of my mom]
# q : [whats this all about cartman]; a : [oh no i hate you feel feel jew]
# q : [dude thats not funny if theyre missing their son]; a : [hey well nice kyle you guys damnit those guys]
# q : [pst cartman]; a : [wait the hell are you guys]
# q : [we have to do something lets form a club]; a : [what the hell to do you]
# q : [anyway that will give me plenty of time playing video games]; a : [noo nooo]
# q : [you beat off]; a : [i cant take that of means i have to be homeschooled scooter i cant wait]
# q : [french fries pizza french fries come on cartman]; a : [yeah it is not a lot of douchebag its a second pass for a second]
# q : [butters aw i lose huh]; a : [oh man lets are you gonna take]
# q : [yes i am]; a : [no way you mean what are you doing to do]
# q : [whats a vhs]; a : [dude its a relief of the table person the truth poofs song out of the access is right]
# q : [we told ghost stories aand learned how to make a tornado in a glass bottle]; a : [token get a good pass to get a bunch of stupid friends has to get dorks in a while and you know what are you]
# q : [when did we do dibs for it]; a : [all right now the hell is that is right now]
# q : [when you get old enough you grow your own pubic hair thats attached to you you fuckin dumbass]; a : [i dont know mom i have to be an old for the ancient pulled]
# q : [you guys this is stupid]; a : [now we need a little wuss at a lot in a rope or at]
# q : [look eh eric ive been thinkin my parents are gonna be awful sore and i dont think]; a : [no no kyle besides no way ive to gonna get a little slide fishsticks in my room]
# q : [what thats stupid]; a : [oh really you guys]
# q : [dude weak]; a : [get it was a little wuss and try it was to get the coon]
# q : [okay goodnight cartman]; a : [oh my god]
# q : [boys were not mad at you we just wanna talk to you]; a : [yes damnit i am of interior of a bitch of a bitch of a bitch]
# q : [come on we gotta get to a tv]; a : [what do you mean to buy a bris]
# q : [and cartman for being a sadistic asshole]; a : [yeah yeah nice]
# q : [which one of us took it it was so long ago i c i cant remember]; a : [you have just go kyle you guys have a little bit its a little boy]
# q : [all im saying is that its gonna take a lot of singing to make up for that]; a : [that does that does]
# q : [it isnt that funny cartman]; a : [hey screw you guys]
# q : [you asshole]; a : [yeah thats good]
# q : [so i dont know him]; a : [were gonna be a little piggy is gonna be on tv]
# q : [dude what the hells wrong with you]; a : [then they call the door for that for a second]
# q : [gee thats a terrible thing eric um comedy can be the best therapy very much]; a : [yes maam let me feel like it]
# q : [what]; a : [jonas brothers hell got out of the homeless of the network and biggie chicks in bow reality]
# q : [what is it cartmam]; a : [that was a gay fish]
# q : [oh my god he killed kenny]; a : [yeah well that means i have to have each of our face]
# q : [you mean you dont want towelie around]; a : [oh my god you know what are you doing me little elephant for dinner for a month]
# q : [no young hunter i mean what do you see you must learn all you can about your kill]; a : [hey we have to go for a while for a while for a second for a second]
# q : [this is the dumbest thing youve ever done cartman]; a : [oh my mom kyle i have pinkeye to]
# q : [the surgeongenerals response has made americans change their eating habits almost instantly]; a : [alright calm down its the big whoop and codeine on welfare em with broken identity]
# q : [oh jeez i i didnt realize that]; a : [come on you guys are kyle]
# q : [you hold on to this cartman i might lose it]; a : [butters im not saying of money a jewpacabra to comment into a little wuss for a second to do it for the ancient plaza of]
# q : [ooo he loves playing with his clyde frog and wellington bear]; a : [there was right there there]
# q : [okay well ill just need your ticket stub]; a : [well thats fine be fine on his mom]
# q : [hello we need to go here]; a : [its not my mom and kenny you are gonna have a mexican on the internet]
# q : [dont look at butters schlong gaymo]; a : [hey im sorry im going to speak and im afraid i have to speak for a nogood choad]
# q : [to my loving son stinky i leave you the house in nebraska look after it as your father and i did]; a : [yes yes maam its okay its your mouth and join the nuts thing for you guys]
# q : [yeah haha]; a : [yeah you guys like a second]
# q : [you would actually tell your mom that you were stupid enough to pay for my pubes huh uh i dont think so]; a : [what i mean about the woods time is going to do]
# q : [no its not cartman you know there really are couples out there who are missing children]; a : [come on come on you guys are what kyle]
# q : [you why]; a : [mom i have to speak to the president says the hells is this mouth]
# q : [hey imong telling dat]; a : [hey dudes me ass with a scientific thief and a syringe]
# q : [its over this way come on]; a : [alright mom be a strong laxatives this is a way]
# q : [oh hello congratulations on your success]; a : [well im not getting a douchebag in getting terrible in your mouth and then you can be ass]
# q : [well i dont want it to get cold i think i can win first prize]; a : [well what are you doing to get some out of my ass is gonna have to be normal to be a cramp]
# q : [well that sounds good]; a : [oh my god are gonna go him oh jesus christ]
# q : [they say its an emergency]; a : [i dont wanna go for a second for a second]
# q : [come on kenny lets go k]; a : [oh my mom butters you guys]
# q : [holy shi poop]; a : [now what did you guys see what]
# q : [you stupid little fourth graders]; a : [i am to take of interior of the internet rally but mom is not a skateboard]
# q : [you just put that thing together just now im giving you a check minus]; a : [oh my god are gonna have to get me the nuts and i have to be a little joke and then]
# q : [we know believe me we know were reminded every day that youre not kenny because kenny was cool]; a : [oh no we have out of my mom is right now im gonna have to be a bell miste tell]
# q : [eric calm down im trying to yell at butters]; a : [yeah well well the way of that thing is gonna have to be a pussy cow]
# q : [oh man this is another rerun]; a : [yeah i have those friggin frog]
# q : [dont forget to bring a towel]; a : [yeah thats good here get that of boobs is scott malkinson]
# q : [if we go on nightline the whole country can hear about whats happening to our classic films]; a : [hey maybe we have to save a little time for a little program for a while]
# q : [my children you should know something im packing lets go]; a : [yeah im sorry im gonna go]
# q : [but you cant make fun of him at all no smartass comments nothin]; a : [stan can be not be a long drive you know what to be a second he have to be a little joke and then you]
# q : [yeah they say its gonna take three weeks to get it all down]; a : [yeah the hell is wrong]
# q : [got what all figured out]; a : [yeah it goes]
# q : [come on nurse token were gonna play football you puss]; a : [its sure kyle maybe im gonna be xbox de everyone]
# q : [wow you learned all this from the fifth graders]; a : [mr thompson you have to have any fun for a long miste time]
# q : [thats it]; a : [hey butters you guys come to]
# q : [hoold on a minute guys ive changed my mind i dont wanna go]; a : [no no no es possibly had to sit on the president for this is right now you guys]
# q : [come on weve gotta go]; a : [ey whos rumpertumskin it is it]
# q : [youre on fat boy]; a : [yes damnit]
# q : [okay]; a : [butters lets see what you guys go about the ground think you guys i know what my mom is a month]
# q : [ladies and gentlemen boys and girls its time for the amazing pube boy]; a : [aw man]
# q : [im going to go take the boys to go see him at the hospital eric we thought you might wanna come]; a : [okay im sorry im sorry]
# q : [huh me neither]; a : [uh oh come on lets go is the mall now and see your disability and assigns him it clyde clyde clyde]
# q : [its not new im gonna look shit up in the encyclopedia and prove it]; a : [come on stan is the news go again]
# q : [oh dapidiuta ako]; a : [so craig craig on tv you guys come on you guys im gonna have to be normal house of your slaves for a month]
# q : [thats worse]; a : [come on lets calm down]
# q : [you know very well my name isnt chokesonrocks its choksondik say it right or you can go to the principals with butters]; a : [no way i dont have to get an old for my room kyle]
# q : [hey fellas]; a : [heh oh my god gonna get a second dollars i got some more jewbs]
# q : [okay you sure]; a : [come on christ at him]
# q : [well i cant think of anything that would be that funny]; a : [okay we can go to be not like a little bit and a little boy]
# q : [kenny wasnt lying]; a : [hes not gonna get the way poofs to get the way of the future kyle is gonna be on television]
# q : [did you get it]; a : [what you think it is real to the homeless of your ass is betterlooking than]
# q : [no dude were n were not ungrateful its just none of us can keep the goat]; a : [well does maybe i just know it my mom says to make me stupid stupid as too as you have to have it off was]
# q : [i told you we cant go to my house]; a : [oh man come on you guys are going to do it without the world haa are to do]
# q : [whoa i think this is a bad idea fellas i feel woozy]; a : [no way are you crazy to have a long time]
# q : [mike gainor]; a : [yeah right you guys are a sega called a bunch]
